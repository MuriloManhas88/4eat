# %% [markdown]
#  - Murilo Manhas, Gabriel Gomes, Nicolas Bueno, Ian Akio

# %%
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from sklearn.metrics import accuracy_score

# %%
import pandas as pd
df =  pd.read_excel('banco_dk.xlsx')
dados = pd.DataFrame(df)
df
# Out:
#    Daiki 2015  Aluguel Daiki+Sala Sena Madureira (50%)+IPTU  \
# 0         jan                                          6000
# 1         fev                                          6218
# 2         mar                                          6218
# 3         abr                                          6218
# 4         mai                                          6218
# 5         jun                                          6218
# 6         jul                                          6218
# 7         ago                                          8318
# 8         set                                          8268
# 9         out                                          8268
# 10        nov                                          8268
# 11        dez                                          8100
# 12      total                                         84530
# 13      Média                                          7044
#
# ...

# %% [markdown]
# ## Analise de dados

# %%
print(df.head())
print(df.shape)
# Out:
#   Daiki 2015  Aluguel Daiki+Sala Sena Madureira (50%)+IPTU  \
# 0        jan                                          6000
# 1        fev                                          6218
# 2        mar                                          6218
# 3        abr                                          6218
# 4        mai                                          6218
#
#    Aluguel Jairo+IPTU+Cond+Seguro+Gasolina  Salários+Pró Labore+VT  \
# 0                                     1795                   22699
# 1                                     1836                   23428
# 2                                     2012                   23521
# 3                                     2012                   23268
# 4                                     2030                   23605
#
#    Gorjetas+Campanha Vinhos+Free Lance  Férias/13o. Salário/Rescisão  \
# 0                                11103                          2392
# ...

# %%
print(df.dtypes)
# Defnindo o tipo de variavel do banco de dados
# Out:
# Daiki 2015                                                                 object
# Aluguel Daiki+Sala Sena Madureira (50%)+IPTU                                int64
# Aluguel Jairo+IPTU+Cond+Seguro+Gasolina                                     int64
# Salários+Pró Labore+VT                                                      int64
# Gorjetas+Campanha Vinhos+Free Lance                                         int64
# Férias/13o. Salário/Rescisão                                                int64
# Contador                                                                    int64
# Telefone/Gás                                                                int64
# Sabesp                                                                      int64
# Eletropaulo                                                                 int64
# DARF/INSS/FGTS/GPS/SINDICATO                                                int64
# ...

# %%
#Separando as variáveis X e Y




X = dados[['Contador',
           
           'Investimentos Imovél, Máquinas/Obra Delivery',

           'Tarifas Cartão - ( Cielo,Rede,TR,Alelo,VR ) - 3% + 500,00 máquinas',

           'Salários+Pró Labore+VT',

           'Gorjetas+Campanha Vinhos+Free Lance',

           'Férias/13o. Salário/Rescisão'
           ]].values
Y = dados['Total Geral'].values

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X)
results = model.fit()
predictions = model.predict(X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0041db99ce86> in <module>
#       2 model = sm.OLS(Y, X)
#       3 results = model.fit()
# ----> 4 predictions = model.predict(X)###
#
# /usr/local/lib/python3.8/dist-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     378             exog = self.exog
#     379
# --> 380         return np.dot(exog, params)
#     381
#     382     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (14,7) and (14,7) not aligned: 7 (dim 1) != 14 (dim 0)

# %%
reg = LinearRegression().fit(X, Y)
reg.score(X, Y)

reg.coef_

reg.intercept_

reg.predict(np.array([[3, 5,8,1,5,6]]))
# Out:
# array([159.37968184])

# %%
x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.3)
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

# %%
dados[['Daiki 2015','Total Geral']].plot()

# %%
import os
 
receita_total = float(input("Receita Total: R$ "))
custos = float(input("Custos: R$ "))
 
lucro = receita_total - custos
 
margem_lucro = (lucro / receita_total) * 100
 
print("Margem de Lucro: ", margem_lucro, "%")
# Out:
# Receita Total: R$ 1000
# Custos: R$ 20
# Margem de Lucro:  98.0 %

# %%
 
quantidade_de_pratos = float(input("qtd de pratos: "))
custos_und = float(input("custo: R$ "))
 
Custo_direto = quantidade_de_pratos * custos_und

preço_venda =  float(input("preço_venda: $ "))
Faturamento = quantidade_de_pratos * preço_venda
lucros = Faturamento - Custo_direto

print(":Custo_direto ", Custo_direto, "$")

print(":Seu faturamento será ", Faturamento, "$")

print(":Seu Lucro será ", lucros, "$")

# %%
import joblib

from sklearn.utils.validation import joblib
joblib.dump(reg,'modelo.joblib')

same_data = joblib.load('modelo.joblib')
